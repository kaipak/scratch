# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def weird_func(x):
    x[x == 0] = -1
    y = np.sumsum(x)
    return y

arr_size = 100000
x = np.arange(0, arr_size)
y_pre = np.random.randint(0, 2, arr_size)
y = weird_func(y_pre)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-1abf7403413a> in <module>
#       7 x = np.arange(0, arr_size)
#       8 y_pre = np.random.randint(0, 2, arr_size)
# ----> 9 y = weird_func(y_pre)
#
# <ipython-input-5-1abf7403413a> in weird_func(x)
#       1 def weird_func(x):
#       2     x[x == 0] = -1
# ----> 3     y = np.sumsum(x)
#       4     return y
#       5
#
# AttributeError: module 'numpy' has no attribute 'sumsum'

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 9))

plt.scatter(x, y)
